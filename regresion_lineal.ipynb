# %% [markdown]
# Modelo de Regresión Lineal
# Jorge Guerrero Ruiz
# Analisis de Datos - 202016908

# %%
#Importar las librerias necesarias al entorno de trabajo

import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# Cargar la data 

datos = pd.read_csv ("C:/Users/Jorge/Documents/datasets/regresion_lineal.csv", sep=",")

# %%
# Explorar los datos cargados

datos.columns
datos.info
datos.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
# Visualizar los datos contenidos en el dataset

datos
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
# Generar la gráfica de dispersión para los datos originales

datos.plot.scatter (x="metro", y="precio", color="lightseagreen")
plt.ylabel("Precio")
plt.xlabel("Metro")
plt.grid(axis = 'both', color = 'lightgrey', linestyle = 'dashed')
plt.show()

# %%
# Creador de modelos de regresión lineal

regresion = linear_model.LinearRegression()

# %%
# Agregar los datos dentro de un vector 

metros = datos["metro"].values.reshape((-1,1))

# %%
# Crear el modelo de regresión lineal

modelo = regresion.fit(metros, datos["precio"])

# %%
# Imprimir el punto de intersección y la pendiente de la recta

print ("Intersección(b)", modelo.intercept_)
print ("Pendiente (m)", modelo.coef_)
# Out:
# Intersección(b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
# Definir entradas para el modelo de predicción e imprimir las predicciones

entradas = [[4],[5],[8],[10],[12],[15],[16],[20],[25]]
predicciones = modelo.predict(entradas)
print (predicciones)
# Out:
# [383.84       389.48571429 406.42285714 417.71428571 429.00571429
#  445.94285714 451.58857143 474.17142857 502.4       ]

# %%
# Imprimir la grafica con el modelo de regresión lineal datos originales vs predicciones

datos.plot.scatter(x="metro", y="precio", label="Datos base", color ='lightcoral')
plt.scatter(entradas, predicciones, color="firebrick")
plt.plot (entradas, predicciones, color ="grey", label="Linea de regresión")
plt.xlabel ('metros')
plt.ylabel ('precio')
plt.legend()
plt.grid(axis = 'both', color = 'lightgrey', linestyle = 'dashed')
plt.show()
